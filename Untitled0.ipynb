# %%
a = "안녕하세요" " 저는" " 학생입니다."
print(a)

name = input("이름 입력 : ")
print(name)

a = input("1~10중 선택하시오 :")
b = input("18~20중 선택하시오 :")
c = a + b
print(c)
# Out:
# 안녕하세요 저는 학생입니다.
# 이름 입력 : 석지희
# 석지희
# 1~10중 선택하시오 :4
# 18~20중 선택하시오 :19
# 419
